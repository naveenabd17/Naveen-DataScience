# %%
from bs4 import BeautifulSoup as bs
import requests

# %% [markdown]
# **1.Write a python program to display all the header tags from ‘en.wikipedia.org/wiki/Main_Page’.**

# %%
link1='https://en.wikipedia.org/wiki/Main_Page'

# %%
page1=requests.get(link1)

# %%
page1
# Out:
# <Response [200]>

# %%
page1.content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Wikipedia, the free encyclopedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"19c19b27-7f2c-4f42-9ad8-5d6cfe15afb7","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Main_Page","wgTitle":"Main Page","wgCurRevisionId":1004593520,"wgRevisionId":1004593520,"wgArticleId":15580374,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":[],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Main_Page","wgRelevantArticleId":15580374,"wgIsProbablyEditable":!1,"wgRel
# ...

# %%
soup1=bs(page1.content,'html.parser')

# %%
print(soup1.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Wikipedia, the free encyclopedia
#   </title>
#   <script>
# ...

# %%
Tag=soup1.find_all(['h1','h2','h3','h4','h5','h6'])

# %%
Header_Tag=[]
for i in range(0,len(Tag)):
    Header_Tag.append(Tag[i].get_text())
Header_Tag
# Out:
# ['Main Page',
#  "From today's featured article",
#  'Did you know\xa0...',
#  'In the news',
#  'On this day',
#  "From today's featured list",
#  "Today's featured picture",
#  'Other areas of Wikipedia',
#  "Wikipedia's sister projects",
#  'Wikipedia languages',
#  'Navigation menu',
#  '\nPersonal tools\n',
#  '\nNamespaces\n',
#  '\nVariants\n',
#  '\nViews\n',
#  '\nMore\n',
#  '\nSearch\n',
#  '\nNavigation\n',
#  '\nContribute\n',
#  '\nTools\n',
#  '\nPrint/export\n',
#  '\nIn other projects\n',
#  '\nLanguages\n']

# %%
Header_Tag[:]=[i.lstrip('\n') for i in Header_Tag]
Header_Tag
# Out:
# ['Main Page',
#  "From today's featured article",
#  'Did you know\xa0...',
#  'In the news',
#  'On this day',
#  "From today's featured list",
#  "Today's featured picture",
#  'Other areas of Wikipedia',
#  "Wikipedia's sister projects",
#  'Wikipedia languages',
#  'Navigation menu',
#  'Personal tools\n',
#  'Namespaces\n',
#  'Variants\n',
#  'Views\n',
#  'More\n',
#  'Search\n',
#  'Navigation\n',
#  'Contribute\n',
#  'Tools\n',
#  'Print/export\n',
#  'In other projects\n',
#  'Languages\n']

# %%
Header_Tag[:]=[i.rstrip('\n') for i in Header_Tag]
Header_Tag
# Out:
# ['Main Page',
#  "From today's featured article",
#  'Did you know\xa0...',
#  'In the news',
#  'On this day',
#  "From today's featured list",
#  "Today's featured picture",
#  'Other areas of Wikipedia',
#  "Wikipedia's sister projects",
#  'Wikipedia languages',
#  'Navigation menu',
#  'Personal tools',
#  'Namespaces',
#  'Variants',
#  'Views',
#  'More',
#  'Search',
#  'Navigation',
#  'Contribute',
#  'Tools',
#  'Print/export',
#  'In other projects',
#  'Languages']

# %%
len(Header_Tag)
# Out:
# 23

# %% [markdown]
# **2.Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. Name, IMDB rating, Year of
# release) and make data frame**

# %%
link2='https://www.imdb.com/search/title/?count=100&groups=top_1000&sort=user_rating'

# %%
page=requests.get(link2)

# %%
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'\n\n<!DOCTYPE html>\n<html\n    xmlns:og="http://ogp.me/ns#"\n    xmlns:fb="http://www.facebook.com/2008/fbml">\n    <head>\n         \n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n    <meta name="apple-itunes-app" content="app-id=342792525, app-argument=imdb:///?src=mdot">\n\n\n\n        <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:\'java\'};</script>\n\n<script>\n    if (typeof uet == \'function\') {\n      uet("bb", "LoadTitle", {wb: 1});\n    }\n</script>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>\n        <title>IMDb &quot;Top 1000&quot;\n(Sorted by IMDb Rating Descending) - IMDb</title>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>\n<script>\n    if (typeof uet == \'function\') {\n      uet("be", "LoadTitle", {wb: 1});\n    }\n</scrip
# ...

# %%
soup=bs(page.content,'html.parser')

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta content="app-id=342792525, app-argument=imdb:///?src=mdot" name="apple-itunes-app"/>\n  <script type="text/javascript">\n   var IMDbTimer={starttime: new Date().getTime(),pt:\'java\'};\n  </script>\n  <script>\n   if (typeof uet == \'function\') {\n      uet("bb", "LoadTitle", {wb: 1});\n    }\n  </script>\n  <script>\n   (function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);\n  </script>\n  <title>\n   IMDb "Top 1000"\n(Sorted by IMDb Rating Descending) - IMDb\n  </title>\n  <script>\n   (function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);\n  </script>\n  <script>\n   if (typeof uet == \'function\') {\n      uet("be", "LoadTitle", {wb: 1});\n    }\n  </script>\n  <script>\n   if (typeof 
# ...

# %%
movie=soup.find_all('h3',class_='lister-item-header')

# %%
Movie_Name=[]
for i in range(0,len(movie)):
    Movie_Name.append(movie[i].get_text())
Movie_Name
# Out:
# ['\n1.\nThe Shawshank Redemption\n(1994)\n',
#  '\n2.\nThe Godfather\n(1972)\n',
#  '\n3.\nSoorarai Pottru\n(2020)\n',
#  '\n4.\nThe Dark Knight\n(2008)\n',
#  '\n5.\nThe Godfather: Part II\n(1974)\n',
#  '\n6.\n12 Angry Men\n(1957)\n',
#  '\n7.\nThe Lord of the Rings: The Return of the King\n(2003)\n',
#  '\n8.\nPulp Fiction\n(1994)\n',
#  "\n9.\nSchindler's List\n(1993)\n",
#  '\n10.\nInception\n(2010)\n',
#  '\n11.\nFight Club\n(1999)\n',
#  '\n12.\nThe Lord of the Rings: The Fellowship of the Ring\n(2001)\n',
#  '\n13.\nForrest Gump\n(1994)\n',
#  '\n14.\nIl buono, il brutto, il cattivo\n(1966)\n',
#  '\n15.\nThe Lord of the Rings: The Two Towers\n(2002)\n',
#  '\n16.\nThe Matrix\n(1999)\n',
#  '\n17.\nGoodfellas\n(1990)\n',
#  '\n18.\nStar Wars: Episode V - The Empire Strikes Back\n(1980)\n',
#  "\n19.\nOne Flew Over the Cuckoo's Nest\n(1975)\n",
#  '\n20.\nGisaengchung\n(2019)\n',
#  '\n21.\nInterstellar\n(2014)\n',
#  '\n22.\nCidade de Deus\n(2002)\n',
# ...

# %%
Movie_Name1=[]
for i in range(0,9):
    Movie_Name1.append(Movie_Name[i][4:-8])
Movie_Name1
# Out:
# ['The Shawshank Redemption',
#  'The Godfather',
#  'Soorarai Pottru',
#  'The Dark Knight',
#  'The Godfather: Part II',
#  '12 Angry Men',
#  'The Lord of the Rings: The Return of the King',
#  'Pulp Fiction',
#  "Schindler's List"]

# %%
Movie_Name2=[]
for i in range(9,99):
    Movie_Name2.append(Movie_Name[i][5:-8])
Movie_Name2
# Out:
# ['Inception',
#  'Fight Club',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'Forrest Gump',
#  'Il buono, il brutto, il cattivo',
#  'The Lord of the Rings: The Two Towers',
#  'The Matrix',
#  'Goodfellas',
#  'Star Wars: Episode V - The Empire Strikes Back',
#  "One Flew Over the Cuckoo's Nest",
#  'Gisaengchung',
#  'Interstellar',
#  'Cidade de Deus',
#  'Sen to Chihiro no kamikakushi',
#  'Saving Private Ryan',
#  'The Green Mile',
#  'La vita è bella',
#  'Se7en',
#  'The Silence of the Lambs',
#  'Star Wars',
#  'Seppuku',
#  'Shichinin no samurai',
#  "It's a Wonderful Life",
#  'Hamilton',
#  'Ratsasan',
#  'Whiplash',
#  'The Intouchables',
#  'The Prestige',
#  'The Departed',
#  'The Pianist',
#  'Gladiator',
#  'American History X',
#  'The Usual Suspects',
#  'Léon',
#  'The Lion King',
#  'Terminator 2: Judgment Day',
#  'Nuovo Cinema Paradiso',
#  'Hotaru no haka',
#  'Back to the Future',
#  'Once Upon a Time in the West',
#  'Psycho',
# ...

# %%
Movie_Namee=Movie_Name1+Movie_Name2

# %%
Movie_Namee.append(Movie_Name[99][6:-8])

# %%
Movie_Namee
# Out:
# ['The Shawshank Redemption',
#  'The Godfather',
#  'Soorarai Pottru',
#  'The Dark Knight',
#  'The Godfather: Part II',
#  '12 Angry Men',
#  'The Lord of the Rings: The Return of the King',
#  'Pulp Fiction',
#  "Schindler's List",
#  'Inception',
#  'Fight Club',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'Forrest Gump',
#  'Il buono, il brutto, il cattivo',
#  'The Lord of the Rings: The Two Towers',
#  'The Matrix',
#  'Goodfellas',
#  'Star Wars: Episode V - The Empire Strikes Back',
#  "One Flew Over the Cuckoo's Nest",
#  'Gisaengchung',
#  'Interstellar',
#  'Cidade de Deus',
#  'Sen to Chihiro no kamikakushi',
#  'Saving Private Ryan',
#  'The Green Mile',
#  'La vita è bella',
#  'Se7en',
#  'The Silence of the Lambs',
#  'Star Wars',
#  'Seppuku',
#  'Shichinin no samurai',
#  "It's a Wonderful Life",
#  'Hamilton',
#  'Ratsasan',
#  'Whiplash',
#  'The Intouchables',
#  'The Prestige',
#  'The Departed',
#  'The Pianist',
#  'Gladiator',
# ...

# %%
len(Movie_Namee)
# Out:
# 100

# %%
Movie_Names=Movie_Namee

# %%
Movie_Names
# Out:
# ['The Shawshank Redemption',
#  'The Godfather',
#  'Soorarai Pottru',
#  'The Dark Knight',
#  'The Godfather: Part II',
#  '12 Angry Men',
#  'The Lord of the Rings: The Return of the King',
#  'Pulp Fiction',
#  "Schindler's List",
#  'Inception',
#  'Fight Club',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'Forrest Gump',
#  'Il buono, il brutto, il cattivo',
#  'The Lord of the Rings: The Two Towers',
#  'The Matrix',
#  'Goodfellas',
#  'Star Wars: Episode V - The Empire Strikes Back',
#  "One Flew Over the Cuckoo's Nest",
#  'Gisaengchung',
#  'Interstellar',
#  'Cidade de Deus',
#  'Sen to Chihiro no kamikakushi',
#  'Saving Private Ryan',
#  'The Green Mile',
#  'La vita è bella',
#  'Se7en',
#  'The Silence of the Lambs',
#  'Star Wars',
#  'Seppuku',
#  'Shichinin no samurai',
#  "It's a Wonderful Life",
#  'Hamilton',
#  'Ratsasan',
#  'Whiplash',
#  'The Intouchables',
#  'The Prestige',
#  'The Departed',
#  'The Pianist',
#  'Gladiator',
# ...

# %%
year=soup.find_all('span',class_='lister-item-year text-muted unbold')

# %%
Year=[]
for i in range(0,100):
    Year.append(year[i].get_text())
Year
# Out:
# ['(1994)',
#  '(1972)',
#  '(2020)',
#  '(2008)',
#  '(1974)',
#  '(1957)',
#  '(2003)',
#  '(1994)',
#  '(1993)',
#  '(2010)',
#  '(1999)',
#  '(2001)',
#  '(1994)',
#  '(1966)',
#  '(2002)',
#  '(1999)',
#  '(1990)',
#  '(1980)',
#  '(1975)',
#  '(2019)',
#  '(2014)',
#  '(2002)',
#  '(2001)',
#  '(1998)',
#  '(1999)',
#  '(1997)',
#  '(1995)',
#  '(1991)',
#  '(1977)',
#  '(1962)',
#  '(1954)',
#  '(1946)',
#  '(2020)',
#  '(2018)',
#  '(2014)',
#  '(2011)',
#  '(2006)',
#  '(2006)',
#  '(2002)',
#  '(2000)',
#  '(1998)',
#  '(1995)',
#  '(1994)',
#  '(1994)',
#  '(1991)',
#  '(1988)',
#  '(1988)',
#  '(1985)',
#  '(1968)',
#  '(1960)',
#  '(1954)',
#  '(1942)',
#  '(1936)',
#  '(1931)',
#  '(2018)',
#  '(2019)',
#  '(2017)',
#  '(2017)',
#  '(2016)',
#  '(2016)',
#  '(2018)',
#  '(2019)',
#  '(2018)',
#  '(I) (2017)',
#  '(2012)',
#  '(2012)',
#  '(2009)',
#  '(2007)',
#  '(2008)',
#  '(2006)',
#  '(2003)',
#  '(2000)',
#  '(1997)',
#  '(1984)',
#  '(1981)',
#  '(1980)',
# ...

# %%
Year_of_release=[]
for i in range(0,100):
    Year_of_release.append(Year[i][1:-1])
Year_of_release
# Out:
# ['1994',
#  '1972',
#  '2020',
#  '2008',
#  '1974',
#  '1957',
#  '2003',
#  '1994',
#  '1993',
#  '2010',
#  '1999',
#  '2001',
#  '1994',
#  '1966',
#  '2002',
#  '1999',
#  '1990',
#  '1980',
#  '1975',
#  '2019',
#  '2014',
#  '2002',
#  '2001',
#  '1998',
#  '1999',
#  '1997',
#  '1995',
#  '1991',
#  '1977',
#  '1962',
#  '1954',
#  '1946',
#  '2020',
#  '2018',
#  '2014',
#  '2011',
#  '2006',
#  '2006',
#  '2002',
#  '2000',
#  '1998',
#  '1995',
#  '1994',
#  '1994',
#  '1991',
#  '1988',
#  '1988',
#  '1985',
#  '1968',
#  '1960',
#  '1954',
#  '1942',
#  '1936',
#  '1931',
#  '2018',
#  '2019',
#  '2017',
#  '2017',
#  '2016',
#  '2016',
#  '2018',
#  '2019',
#  '2018',
#  'I) (2017',
#  '2012',
#  '2012',
#  '2009',
#  '2007',
#  '2008',
#  '2006',
#  '2003',
#  '2000',
#  '1997',
#  '1984',
#  '1981',
#  '1980',
#  '1979',
#  '1979',
#  '1963',
#  '1964',
#  '1957',
#  '1957',
#  '1950',
#  '1940',
#  '2019',
#  '2019',
#  '2018',
#  '2013',
#  '2012',
#  '2011',
# ...

# %%
Rating=soup.find_all('div',class_='inline-block ratings-imdb-rating')

# %%
len(Rating)
# Out:
# 100

# %%
Ratings=[]
for i in range(0,100):
    Ratings.append(Rating[i].get_text())
Ratings
# Out:
# ['\n\n9.3\n',
#  '\n\n9.2\n',
#  '\n\n9.1\n',
#  '\n\n9.0\n',
#  '\n\n9.0\n',
#  '\n\n9.0\n',
#  '\n\n8.9\n',
#  '\n\n8.9\n',
#  '\n\n8.9\n',
#  '\n\n8.8\n',
#  '\n\n8.8\n',
#  '\n\n8.8\n',
#  '\n\n8.8\n',
#  '\n\n8.8\n',
#  '\n\n8.7\n',
#  '\n\n8.7\n',
#  '\n\n8.7\n',
#  '\n\n8.7\n',
#  '\n\n8.7\n',
#  '\n\n8.6\n',
#  '\n\n8.6\n',
#  '\n\n8.6\n',
#  '\n\n8.6\n',
#  '\n\n8.6\n',
#  '\n\n8.6\n',
#  '\n\n8.6\n',
#  '\n\n8.6\n',
#  '\n\n8.6\n',
#  '\n\n8.6\n',
#  '\n\n8.6\n',
#  '\n\n8.6\n',
#  '\n\n8.6\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.4\n',
#  '\n\n8.4\n',
#  '\n\n8.4\n',
#  '\n\n8.4\n',
#  '\n\n8.4\n',
#  '\n\n8.4\n',
#  '\n\n8.4\n',
#  '\n\n8.4\n',
# ...

# %%
Ratings1=[]
for i in range(0,100):
    Ratings1.append(Ratings[i][2:-1])
len(Ratings1)
# Out:
# 100

# %%
Movie_Rating=Ratings1

# %%
import pandas as pd

# %%
df=pd.DataFrame()

# %%
df['Movie Name']=Movie_Names

# %%
df['IMDB Ratings']=Movie_Rating

# %%
df['Year Of Release']=Year_of_release

# %%
df.head()
# Out:
#                  Movie Name IMDB Ratings Year Of Release
# 0  The Shawshank Redemption          9.3            1994
# 1             The Godfather          9.2            1972
# 2           Soorarai Pottru          9.1            2020
# 3           The Dark Knight          9.0            2008
# 4    The Godfather: Part II          9.0            1974

# %%
df.shape
# Out:
# (100, 3)

# %% [markdown]
# **3.Write a python program to display IMDB’s Top rated 100 Indian movies’ data (i.e. Name, IMDB rating, Year
# of release) and make data frame.**

# %%
link3='https://www.imdb.com/india/top-rated-indian-movies/'

# %%
page=requests.get(link3)

# %%
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'\n\n\n<!DOCTYPE html>\n<html\n    xmlns:og="http://ogp.me/ns#"\n    xmlns:fb="http://www.facebook.com/2008/fbml">\n    <head>\n         \n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n    \n    \n    \n\n    \n    \n    \n\n    <meta name="apple-itunes-app" content="app-id=342792525, app-argument=imdb:///?src=mdot">\n            <style>\n                body#styleguide-v2 {\n                    background: no-repeat fixed center top #000;\n                }\n            </style>\n        <style>\n            body#styleguide-v2 #root {\n                box-shadow: none;\n            }\n        </style>\n\n\n\n        <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:\'java\'};</script>\n\n<script>\n    if (typeof uet == \'function\') {\n      uet("bb", "LoadTitle", {wb: 1});\n    }\n</script>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer
# ...

# %%
soup=bs(page.content,'html.parser')

# %%
soup.title.text
# Out:
# 'Top Rated Indian Movies - IMDb'

# %%
movie1=soup.find_all('td',class_='titleColumn')
movie1
# Out:
# [<td class="titleColumn">
#        1.
#        <a href="/title/tt0048473/" title="Satyajit Ray (dir.), Kanu Bannerjee, Karuna Bannerjee">Pather Panchali</a>
#  <span class="secondaryInfo">(1955)</span>
#  </td>,
#  <td class="titleColumn">
#        2.
#        <a href="/title/tt0093603/" title="Mani Ratnam (dir.), Kamal Haasan, Saranya Ponvannan">Nayakan</a>
#  <span class="secondaryInfo">(1987)</span>
#  </td>,
#  <td class="titleColumn">
#        3.
#        <a href="/title/tt0367495/" title="Sundar C. (dir.), Kamal Haasan, Madhavan">Anbe Sivam</a>
#  <span class="secondaryInfo">(2003)</span>
#  </td>,
#  <td class="titleColumn">
#        4.
#        <a href="/title/tt8176054/" title="Mari Selvaraj (dir.), Kathir, Anandhi">Pariyerum Perumal</a>
#  <span class="secondaryInfo">(2018)</span>
#  </td>,
#  <td class="titleColumn">
#        5.
#        <a href="/title/tt12361178/" title="Jeethu Joseph (dir.), Mohanlal, Meena">Drishyam 2</a>
#  <span class="secondaryInfo">(2021)</span>
# ...

# %%
movies2=[]
for i in range(0,100):
    movies2.append(movie1[i].get_text())
movies2
# Out:
# ['\n      1.\n      Pather Panchali\n(1955)\n',
#  '\n      2.\n      Nayakan\n(1987)\n',
#  '\n      3.\n      Anbe Sivam\n(2003)\n',
#  '\n      4.\n      Pariyerum Perumal\n(2018)\n',
#  '\n      5.\n      Drishyam 2\n(2021)\n',
#  '\n      6.\n      Gol Maal\n(1979)\n',
#  '\n      7.\n      Apur Sansar\n(1959)\n',
#  '\n      8.\n      C/o Kancharapalem\n(2018)\n',
#  '\n      9.\n      Kireedam\n(1989)\n',
#  '\n      10.\n      Natsamrat\n(2016)\n',
#  '\n      11.\n      Manichitrathazhu\n(1993)\n',
#  '\n      12.\n      96\n(2018)\n',
#  '\n      13.\n      Black Friday\n(2004)\n',
#  '\n      14.\n      Thevar Magan\n(1992)\n',
#  '\n      15.\n      Kumbalangi Nights\n(2019)\n',
#  '\n      16.\n      3 Idiots\n(2009)\n',
#  '\n      17.\n      Visaaranai\n(2015)\n',
#  '\n      18.\n      Taare Zameen Par\n(2007)\n',
#  '\n      19.\n      Ratsasan\n(2018)\n',
#  '\n      20.\n      Jersey\n(2019)\n',
#  '\n      21.\n      Thalapathi\n(1991)\n',
# ...

# %%
movies2[:]=[i.strip('\n') for i in movies2]
movies2
# Out:
# ['      1.\n      Pather Panchali\n(1955)',
#  '      2.\n      Nayakan\n(1987)',
#  '      3.\n      Anbe Sivam\n(2003)',
#  '      4.\n      Pariyerum Perumal\n(2018)',
#  '      5.\n      Drishyam 2\n(2021)',
#  '      6.\n      Gol Maal\n(1979)',
#  '      7.\n      Apur Sansar\n(1959)',
#  '      8.\n      C/o Kancharapalem\n(2018)',
#  '      9.\n      Kireedam\n(1989)',
#  '      10.\n      Natsamrat\n(2016)',
#  '      11.\n      Manichitrathazhu\n(1993)',
#  '      12.\n      96\n(2018)',
#  '      13.\n      Black Friday\n(2004)',
#  '      14.\n      Thevar Magan\n(1992)',
#  '      15.\n      Kumbalangi Nights\n(2019)',
#  '      16.\n      3 Idiots\n(2009)',
#  '      17.\n      Visaaranai\n(2015)',
#  '      18.\n      Taare Zameen Par\n(2007)',
#  '      19.\n      Ratsasan\n(2018)',
#  '      20.\n      Jersey\n(2019)',
#  '      21.\n      Thalapathi\n(1991)',
#  '      22.\n      Dangal\n(2016)',
#  '      23.\n      Soorarai Pottru\n(2020)',
# ...

# %%
movies2[0][15:-7]
# Out:
# 'Pather Panchali'

# %%
movies2[9][16:-7]
# Out:
# 'Natsamrat'

# %%
movies2[99][17:-7]
# Out:
# 'Iqbal'

# %%
Movies_Name1=[]
for i in range(0,9):
    Movies_Name1.append(movies2[i][15:-7])
Movies_Name1
# Out:
# ['Pather Panchali',
#  'Nayakan',
#  'Anbe Sivam',
#  'Pariyerum Perumal',
#  'Drishyam 2',
#  'Gol Maal',
#  'Apur Sansar',
#  'C/o Kancharapalem',
#  'Kireedam']

# %%
for i in range(9,99):
    Movies_Name1.append(movies2[i][16:-7])
Movies_Name1
# Out:
# ['Pather Panchali',
#  'Nayakan',
#  'Anbe Sivam',
#  'Pariyerum Perumal',
#  'Drishyam 2',
#  'Gol Maal',
#  'Apur Sansar',
#  'C/o Kancharapalem',
#  'Kireedam',
#  'Natsamrat',
#  'Manichitrathazhu',
#  '96',
#  'Black Friday',
#  'Thevar Magan',
#  'Kumbalangi Nights',
#  '3 Idiots',
#  'Visaaranai',
#  'Taare Zameen Par',
#  'Ratsasan',
#  'Jersey',
#  'Thalapathi',
#  'Dangal',
#  'Soorarai Pottru',
#  'Devasuram',
#  'Asuran',
#  'Aparajito',
#  'Kaithi',
#  'Jaane Bhi Do Yaaro',
#  'Pyaasa',
#  'Guide',
#  'Peranbu',
#  'Vada Chennai',
#  'Thani Oruvan',
#  'Kannathil Muthamittal',
#  'Chupke Chupke',
#  'Spadikam',
#  'Iruvar',
#  'Vikram Vedha',
#  'Drishyam',
#  'Agent Sai Srinivasa Athreya',
#  'Aruvi',
#  'Super Deluxe',
#  'Tumbbad',
#  'Mahanati',
#  'Khosla Ka Ghosla!',
#  'Anand',
#  'Pudhu Pettai',
#  'Premam',
#  'Kaakkaa Muttai',
#  'Anniyan',
#  'Andhadhun',
#  'Bangalore Days',
#  'Mudhalvan',
#  'Dhuruvangal Pathinaaru',
#  'Papanasam',
#  'Satya',
# ...

# %%
Movies_Name1.append(movies2[99][17:-7])

# %%
len(Movies_Name1)
# Out:
# 100

# %%
ratings3=soup.find_all('td',class_='ratingColumn imdbRating')

# %%
ratings31=[]
for i in range(0,100):
    ratings31.append(ratings3[i].get_text())
ratings31[:]=[i.strip('\n') for i in ratings31]
len(ratings31)
# Out:
# 100

# %%
year3=soup.find_all('td',class_='titleColumn')

# %%
year3
# Out:
# [<td class="titleColumn">
#        1.
#        <a href="/title/tt0048473/" title="Satyajit Ray (dir.), Kanu Bannerjee, Karuna Bannerjee">Pather Panchali</a>
#  <span class="secondaryInfo">(1955)</span>
#  </td>,
#  <td class="titleColumn">
#        2.
#        <a href="/title/tt0093603/" title="Mani Ratnam (dir.), Kamal Haasan, Saranya Ponvannan">Nayakan</a>
#  <span class="secondaryInfo">(1987)</span>
#  </td>,
#  <td class="titleColumn">
#        3.
#        <a href="/title/tt0367495/" title="Sundar C. (dir.), Kamal Haasan, Madhavan">Anbe Sivam</a>
#  <span class="secondaryInfo">(2003)</span>
#  </td>,
#  <td class="titleColumn">
#        4.
#        <a href="/title/tt8176054/" title="Mari Selvaraj (dir.), Kathir, Anandhi">Pariyerum Perumal</a>
#  <span class="secondaryInfo">(2018)</span>
#  </td>,
#  <td class="titleColumn">
#        5.
#        <a href="/title/tt12361178/" title="Jeethu Joseph (dir.), Mohanlal, Meena">Drishyam 2</a>
#  <span class="secondaryInfo">(2021)</span>
# ...

# %%
year31=[]
for i in range(0,100):
    year31.append(year3[i].get_text())
year31
# Out:
# ['\n      1.\n      Pather Panchali\n(1955)\n',
#  '\n      2.\n      Nayakan\n(1987)\n',
#  '\n      3.\n      Anbe Sivam\n(2003)\n',
#  '\n      4.\n      Pariyerum Perumal\n(2018)\n',
#  '\n      5.\n      Drishyam 2\n(2021)\n',
#  '\n      6.\n      Gol Maal\n(1979)\n',
#  '\n      7.\n      Apur Sansar\n(1959)\n',
#  '\n      8.\n      C/o Kancharapalem\n(2018)\n',
#  '\n      9.\n      Kireedam\n(1989)\n',
#  '\n      10.\n      Natsamrat\n(2016)\n',
#  '\n      11.\n      Manichitrathazhu\n(1993)\n',
#  '\n      12.\n      96\n(2018)\n',
#  '\n      13.\n      Black Friday\n(2004)\n',
#  '\n      14.\n      Thevar Magan\n(1992)\n',
#  '\n      15.\n      Kumbalangi Nights\n(2019)\n',
#  '\n      16.\n      3 Idiots\n(2009)\n',
#  '\n      17.\n      Visaaranai\n(2015)\n',
#  '\n      18.\n      Taare Zameen Par\n(2007)\n',
#  '\n      19.\n      Ratsasan\n(2018)\n',
#  '\n      20.\n      Jersey\n(2019)\n',
#  '\n      21.\n      Thalapathi\n(1991)\n',
# ...

# %%
year31[:]=[i.strip('\n') for i in year31]
year31
# Out:
# ['      1.\n      Pather Panchali\n(1955)',
#  '      2.\n      Nayakan\n(1987)',
#  '      3.\n      Anbe Sivam\n(2003)',
#  '      4.\n      Pariyerum Perumal\n(2018)',
#  '      5.\n      Drishyam 2\n(2021)',
#  '      6.\n      Gol Maal\n(1979)',
#  '      7.\n      Apur Sansar\n(1959)',
#  '      8.\n      C/o Kancharapalem\n(2018)',
#  '      9.\n      Kireedam\n(1989)',
#  '      10.\n      Natsamrat\n(2016)',
#  '      11.\n      Manichitrathazhu\n(1993)',
#  '      12.\n      96\n(2018)',
#  '      13.\n      Black Friday\n(2004)',
#  '      14.\n      Thevar Magan\n(1992)',
#  '      15.\n      Kumbalangi Nights\n(2019)',
#  '      16.\n      3 Idiots\n(2009)',
#  '      17.\n      Visaaranai\n(2015)',
#  '      18.\n      Taare Zameen Par\n(2007)',
#  '      19.\n      Ratsasan\n(2018)',
#  '      20.\n      Jersey\n(2019)',
#  '      21.\n      Thalapathi\n(1991)',
#  '      22.\n      Dangal\n(2016)',
#  '      23.\n      Soorarai Pottru\n(2020)',
# ...

# %%
year312=[]
for i in range(0,100):
    year312.append(year31[i][-5:-1])
    
len(year312)
# Out:
# 100

# %%
df3=pd.DataFrame()

# %%
df3['Movie Name']=Movies_Name1
df3['Ratings']=ratings31
df3['Year of Release']=year312

# %%
df3.head()
# Out:
#           Movie Name Ratings Year of Release
# 0    Pather Panchali     8.5            1955
# 1            Nayakan     8.5            1987
# 2         Anbe Sivam     8.5            2003
# 3  Pariyerum Perumal     8.5            2018
# 4         Drishyam 2     8.5            2021

# %%
df3.shape
# Out:
# (100, 3)

# %% [markdown]
# **4.Write a python program to scrap book name, author name, genre and book review of any 5 books from
# ‘www.bookpage.com’**

# %%
link4='https://bookpage.com/reviews?book_genre=nonfiction&page=1'

# %%
page4=requests.get(link4)

# %%
page4
# Out:
# <Response [200]>

# %%
page4.content
# Out:
# b'<!DOCTYPE html>\n<html lang=\'en\' xmlns:fb=\'http://www.facebook.com/2008/fbml\' xmlns:og=\'http://opengraphprotocol.org/schema/\'>\n<head>\n<title>Nonfiction Book Reviews | BookPage</title>\n<meta name="description" content="Nonfiction book recommendations of the best new books and more.">\n<meta name="keywords" content="book reviews, books and literature, writing and writers">\n<link rel="canonical" href="https://bookpage.com/reviews?book_genre=nonfiction&amp;page=1">\n<meta property="og:site_name" content="BookPage.com">\n<meta property="og:title" content="Nonfiction Book Reviews">\n<meta property="og:description" content="Nonfiction book recommendations of the best new books and more.">\n<meta property="og:type" content="website">\n<meta property="og:url" content="https://bookpage.com/reviews?book_genre=nonfiction&amp;page=1">\n<meta property="og:image" content="//www.bookpage.com/default_image.jpg">\n<meta name="twitter:card" content="summary">\n<meta name="twitter:site" cont
# ...

# %%
soup4=bs(page4.content,'html.parser')

# %%
soup4
# Out:
# <!DOCTYPE html>
#
# <html lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <title>Nonfiction Book Reviews | BookPage</title>
# <meta content="Nonfiction book recommendations of the best new books and more." name="description"/>
# <meta content="book reviews, books and literature, writing and writers" name="keywords"/>
# <link href="https://bookpage.com/reviews?book_genre=nonfiction&amp;page=1" rel="canonical"/>
# <meta content="BookPage.com" property="og:site_name"/>
# <meta content="Nonfiction Book Reviews" property="og:title"/>
# <meta content="Nonfiction book recommendations of the best new books and more." property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://bookpage.com/reviews?book_genre=nonfiction&amp;page=1" property="og:url"/>
# <meta content="//www.bookpage.com/default_image.jpg" property="og:image"/>
# <meta content="summary" name="twitter:card"/>
# ...

# %%
soup4.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">\n <head>\n  <title>\n   Nonfiction Book Reviews | BookPage\n  </title>\n  <meta content="Nonfiction book recommendations of the best new books and more." name="description"/>\n  <meta content="book reviews, books and literature, writing and writers" name="keywords"/>\n  <link href="https://bookpage.com/reviews?book_genre=nonfiction&amp;page=1" rel="canonical"/>\n  <meta content="BookPage.com" property="og:site_name"/>\n  <meta content="Nonfiction Book Reviews" property="og:title"/>\n  <meta content="Nonfiction book recommendations of the best new books and more." property="og:description"/>\n  <meta content="website" property="og:type"/>\n  <meta content="https://bookpage.com/reviews?book_genre=nonfiction&amp;page=1" property="og:url"/>\n  <meta content="//www.bookpage.com/default_image.jpg" property="og:image"/>\n  <meta content="summary" name="twitter:card
# ...

# %%
bookname=soup4.find_all('h4',class_='italic')

# %%
bookname1=[]
for i in range(0,5):
    bookname1.append(bookname[i].get_text())
bookname1[:]=[i.strip('\n') for i in bookname1]

# %%
bookname1
# Out:
# ['New Yorkers',
#  ' ★ American Republics',
#  'Notes on Grief',
#  ' ★ Out of the Shadows',
#  ' ★ Facing the Mountain']

# %%
Book_Name=bookname1

# %%
author=soup4.find_all('p',class_='sans bold')

# %%
author1=[]
for i in range(0,5):
    author1.append(author[i].get_text())
author1[:]=[i.strip('\n') for i in author1]
author1
# Out:
# ['Craig Taylor, Cast',
#  'Alan Taylor',
#  'Chimamanda Ngozi Adichie',
#  'Emily Midorikawa',
#  'Daniel James Brown']

# %%
review=soup4.find_all('p',class_='excerpt')

# %%
review1=[]
for i in range(0,5):
    review1.append(review[i].get_text())
review1[:]=[i.strip('\n') for i in review1]

# %%
review1
# Out:
# ['“This city barged into conversations,” Craig Taylor says about New Yorkers. With that kind of attitude, you’ll have no choice but to listen in.',
#  'Pulitzer Prize winner Alan Taylor’s latest American history is sweeping, beautifully written, prodigiously researched and myth-busting.',
#  'In her slim memoir, Chimamanda Ngozi Adichie pays homage to her father’s remarkable life while observing her own surprising grief.',
#  'Emily Midorikawa unveils the triumphant, tragic and deeply unconventional lives of six of the Victorian era’s best known spirit mediums.',
#  'Most of the Japanese American patriots who formed the 442nd Infantry Regiment are gone, but their stories live on in this empathetic tribute to their courage.']

# %%
df4=pd.DataFrame()

# %%
df4['Book Name']=Book_Name
df4['Author']=author1
df4['Review']=review1

# %%
df4['genre']='Non Fiction'

# %%
df4.head()
# Out:
#                 Book Name                    Author  \
# 0             New Yorkers        Craig Taylor, Cast
# 1    ★ American Republics               Alan Taylor
# 2          Notes on Grief  Chimamanda Ngozi Adichie
# 3    ★ Out of the Shadows          Emily Midorikawa
# 4   ★ Facing the Mountain        Daniel James Brown
#
#                                               Review        genre
# 0  “This city barged into conversations,” Craig T...  Non Fiction
# 1  Pulitzer Prize winner Alan Taylor’s latest Ame...  Non Fiction
# 2  In her slim memoir, Chimamanda Ngozi Adichie p...  Non Fiction
# 3  Emily Midorikawa unveils the triumphant, tragi...  Non Fiction
# 4  Most of the Japanese American patriots who for...  Non Fiction

# %%
df4.shape
# Out:
# (5, 4)

# %% [markdown]
# **5.1.Top 10 ODI teams in men’s cricket along with the records for matches, points and rating**

# %%
link51='https://www.icc-cricket.com/rankings/mens/team-rankings/odi'

# %%
page51=requests.get(link51)

# %%
page51
# Out:
# <Response [200]>

# %%
page51.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="ICC Ranking for ODI teams International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="ICC Ranking for ODI teams International Cricket Council"/>\n<meta proper
# ...

# %%
soup51=bs(page51.content,'html.parser')

# %%
soup51.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n <head>\n  <meta content="ICC Ranking for ODI teams International Cricket Council" name="twitter:title"/>\n  <meta content="website" property="og:type"/>\n  <meta content="summary_large_image" property="twitter:card"/>\n  <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>\n  <meta content="@icc" property="twitter:site"/>\n  <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>\n  <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>\n  <meta content="ICC Ranking for ODI teams International Cricket Council" property="og:title"/>\n  
# ...

# %%
country1=soup51.find_all('span',class_='u-hide-phablet')
country15=[]
for i in range(0,10):
    country15.append(country1[i].get_text())
country15
# Out:
# ['New Zealand',
#  'Australia',
#  'India',
#  'England',
#  'South Africa',
#  'Pakistan',
#  'Bangladesh',
#  'West Indies',
#  'Sri Lanka',
#  'Afghanistan']

# %%
match1=soup51.find_all('td',class_='rankings-block__banner--matches')

# %%
match1=match1[0].get_text()

# %%
match2=soup51.find_all('td',class_='table-body__cell u-center-text')

# %%
match2=match2[0:17]
match2
# Out:
# [<td class="table-body__cell u-center-text">25</td>,
#  <td class="table-body__cell u-center-text">2,945</td>,
#  <td class="table-body__cell u-center-text">29</td>,
#  <td class="table-body__cell u-center-text">3,344</td>,
#  <td class="table-body__cell u-center-text">27</td>,
#  <td class="table-body__cell u-center-text">3,100</td>,
#  <td class="table-body__cell u-center-text">20</td>,
#  <td class="table-body__cell u-center-text">2,137</td>,
#  <td class="table-body__cell u-center-text">24</td>,
#  <td class="table-body__cell u-center-text">2,323</td>,
#  <td class="table-body__cell u-center-text">25</td>,
#  <td class="table-body__cell u-center-text">2,286</td>,
#  <td class="table-body__cell u-center-text">27</td>,
#  <td class="table-body__cell u-center-text">2,222</td>,
#  <td class="table-body__cell u-center-text">22</td>,
#  <td class="table-body__cell u-center-text">1,692</td>,
#  <td class="table-body__cell u-center-text">17</td>]

# %%
match21=[]
for i in range(0,17,2):
    match21.append(match2[i].get_text()) 
match21
# Out:
# ['25', '29', '27', '20', '24', '25', '27', '22', '17']

# %%
match21.insert(0,'17')

# %%
Matches=match21

# %%
points=soup51.find_all('td',class_='table-body__cell u-center-text')

# %%
points=points[0:18]
points
# Out:
# [<td class="table-body__cell u-center-text">25</td>,
#  <td class="table-body__cell u-center-text">2,945</td>,
#  <td class="table-body__cell u-center-text">29</td>,
#  <td class="table-body__cell u-center-text">3,344</td>,
#  <td class="table-body__cell u-center-text">27</td>,
#  <td class="table-body__cell u-center-text">3,100</td>,
#  <td class="table-body__cell u-center-text">20</td>,
#  <td class="table-body__cell u-center-text">2,137</td>,
#  <td class="table-body__cell u-center-text">24</td>,
#  <td class="table-body__cell u-center-text">2,323</td>,
#  <td class="table-body__cell u-center-text">25</td>,
#  <td class="table-body__cell u-center-text">2,286</td>,
#  <td class="table-body__cell u-center-text">27</td>,
#  <td class="table-body__cell u-center-text">2,222</td>,
#  <td class="table-body__cell u-center-text">22</td>,
#  <td class="table-body__cell u-center-text">1,692</td>,
#  <td class="table-body__cell u-center-text">17</td>,
# ...

# %%
Points=[]
for i in range(1,18,2):
    Points.append(points[i].get_text())
Points
# Out:
# ['2,945',
#  '3,344',
#  '3,100',
#  '2,137',
#  '2,323',
#  '2,286',
#  '2,222',
#  '1,692',
#  '1,054']

# %%
Points.insert(0,'2054')

# %%
len(Points)
# Out:
# 10

# %%
ratings51=soup51.find_all('td',class_='table-body__cell u-text-right rating')

# %%
ratings51
# Out:
# [<td class="table-body__cell u-text-right rating">118</td>,
#  <td class="table-body__cell u-text-right rating">115</td>,
#  <td class="table-body__cell u-text-right rating">115</td>,
#  <td class="table-body__cell u-text-right rating">107</td>,
#  <td class="table-body__cell u-text-right rating">97</td>,
#  <td class="table-body__cell u-text-right rating">91</td>,
#  <td class="table-body__cell u-text-right rating">82</td>,
#  <td class="table-body__cell u-text-right rating">77</td>,
#  <td class="table-body__cell u-text-right rating">62</td>,
#  <td class="table-body__cell u-text-right rating">45</td>,
#  <td class="table-body__cell u-text-right rating">39</td>,
#  <td class="table-body__cell u-text-right rating">39</td>,
#  <td class="table-body__cell u-text-right rating">37</td>,
#  <td class="table-body__cell u-text-right rating">34</td>,
#  <td class="table-body__cell u-text-right rating">24</td>,
#  <td class="table-body__cell u-text-right rating">21</td>,
# ...

# %%
Ratings51=[]
for i in range(0,9):
    Ratings51.append(ratings51[i].get_text())
Ratings51
# Out:
# ['118', '115', '115', '107', '97', '91', '82', '77', '62']

# %%
Ratings51.insert(0,'121')

# %%
df51=pd.DataFrame()

# %%
df51['Country']=country15
df51['Matches']=Matches
df51['Points']=Points
df51['Ratings']=Ratings51

# %%
df51.head()
# Out:
#         Country Matches Points Ratings
# 0   New Zealand      17   2054     121
# 1     Australia      25  2,945     118
# 2         India      29  3,344     115
# 3       England      27  3,100     115
# 4  South Africa      20  2,137     107

# %%
df51.shape
# Out:
# (10, 4)

# %% [markdown]
# **5.2.Top 10 ODI Batsmen in men along with the records of their team and rating.**

# %%
link52='https://www.icc-cricket.com/rankings/mens/player-rankings/odi'

# %%
page52=requests.get(link52)

# %%
page52
# Out:
# <Response [200]>

# %%
page52.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="ICC ODI Match Player Rankings International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="ICC ODI Match Player Rankings International Cricket Council"/>\n<meta property="og:image" content=
# ...

# %%
soup52=bs(page52.content,'html.parser')

# %%
soup52.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n <head>\n  <meta content="ICC ODI Match Player Rankings International Cricket Council" name="twitter:title"/>\n  <meta content="website" property="og:type"/>\n  <meta content="summary_large_image" property="twitter:card"/>\n  <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>\n  <meta content="@icc" property="twitter:site"/>\n  <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>\n  <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>\n  <meta content="ICC ODI Match Player Rankings International Cricket Council" property="og:title"/>\n  <meta content="https:/
# ...

# %%
player52=soup52.find_all('td',class_='table-body__cell name')

# %%
Player=[]
for i in range(0,9):
    Player.append(player52[i].get_text())
Player[:]=[i.strip('\n') for i in Player]
Player
# Out:
# ['Virat Kohli',
#  'Rohit Sharma',
#  'Ross Taylor',
#  'Aaron Finch',
#  'Jonny Bairstow',
#  'Fakhar Zaman',
#  'Francois du Plessis',
#  'David Warner',
#  'Shai Hope']

# %%
Player.insert(0,'Babar Azam')

# %%
Player
# Out:
# ['Babar Azam',
#  'Virat Kohli',
#  'Rohit Sharma',
#  'Ross Taylor',
#  'Aaron Finch',
#  'Jonny Bairstow',
#  'Fakhar Zaman',
#  'Francois du Plessis',
#  'David Warner',
#  'Shai Hope']

# %%
Team1=soup52.find_all('span',class_='table-body__logo-text')

# %%
Team=[]
for i in range(0,9):
    Team.append(Team1[i].get_text())
Team[:]=[i.strip('\n') for i in Team]
Team
# Out:
# ['IND', 'IND', 'NZ', 'AUS', 'ENG', 'PAK', 'SA', 'AUS', 'WI']

# %%
Team.insert(0,'PAK')

# %%
Team
# Out:
# ['PAK', 'IND', 'IND', 'NZ', 'AUS', 'ENG', 'PAK', 'SA', 'AUS', 'WI']

# %%
ratings52=soup52.find_all('td',class_='table-body__cell u-text-right rating')

# %%
Ratings52=[]
for i in range(0,9):
    Ratings52.append(ratings52[i].get_text())
Ratings52[:]=[i.strip('\n') for i in Ratings52]
Ratings52
# Out:
# ['857', '825', '801', '791', '785', '778', '778', '773', '773']

# %%
Ratings52.insert(0,'865')

# %%
df52=pd.DataFrame()

# %%
df52['Player Name']=Player
df52['Team']=Team
df52['Ratings']=Ratings52

# %%
df52.head()
# Out:
#     Player Name Team Ratings
# 0    Babar Azam  PAK     865
# 1   Virat Kohli  IND     857
# 2  Rohit Sharma  IND     825
# 3   Ross Taylor   NZ     801
# 4   Aaron Finch  AUS     791

# %%
df52.shape
# Out:
# (10, 3)

# %% [markdown]
# **5.3.Top 10 ODI bowlers along with the records of their team and rating**

# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
link53='https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling'

# %%
page53=requests.get(link53)

# %%
page53
# Out:
# <Response [200]>

# %%
page53.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="Live Cricket Scores & News International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="Live Cricket Scores & News International Cricket Council"/>\n<meta property="og:image" content="https://www.icc-cricket.com/resources/ver/i/elements/defa
# ...

# %%
soup53=bs(page53.content,'html.parser')

# %%
soup53.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n <head>\n  <meta content="Live Cricket Scores &amp; News International Cricket Council" name="twitter:title"/>\n  <meta content="website" property="og:type"/>\n  <meta content="summary_large_image" property="twitter:card"/>\n  <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>\n  <meta content="@icc" property="twitter:site"/>\n  <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>\n  <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>\n  <meta content="Live Cricket Scores &amp; News International Cricket Council" property="og:title"/>\n  <meta content="https://www.icc-cricket.com/resources/ver/i/elements/defa
# ...

# %%
Name53=soup53.find_all('td',class_='table-body__cell rankings-table__name name')

# %%
Name531=[]
for i in range(0,9):
    Name531.append(Name53[i].get_text())
Name531[:]=[i.strip('\n') for i in Name531]
Name531
# Out:
# ['Mujeeb Ur Rahman',
#  'Matt Henry',
#  'Jasprit Bumrah',
#  'Mehedi Hasan',
#  'Kagiso Rabada',
#  'Chris Woakes',
#  'Josh Hazlewood',
#  'Pat Cummins',
#  'Mohammad Amir']

# %%
Name531.insert(0,'Trent Bolt')

# %%
len(Name531)
# Out:
# 10

# %%
Team53=soup53.find_all('span',class_='table-body__logo-text')

# %%
Team531=[]
for i in range(0,9):
    Team531.append(Team53[i].get_text())
Team531[:]=[i.strip('\n') for i in Team531]
Team531
# Out:
# ['AFG', 'NZ', 'IND', 'BAN', 'SA', 'ENG', 'AUS', 'AUS', 'PAK']

# %%
Team531.insert(0,'NZ')

# %%
Rating53=soup53.find_all('td',class_='table-body__cell rating')

# %%
Rating531=[]
for i in range(0,9):
    Rating531.append(Rating53[i].get_text())
Rating531[:]=[i.strip('\n') for i in Rating531]
Rating531
# Out:
# ['708', '691', '690', '668', '666', '665', '660', '646', '638']

# %%
Rating531.insert(0,'737')

# %%
import pandas as pd
df53=pd.DataFrame()

# %%
df53['Player Name']=Name531
df53['Team']=Team531
df53['Ratings']=Rating531

# %%
df53.head()
# Out:
#         Player Name Team Ratings
# 0        Trent Bolt   NZ     737
# 1  Mujeeb Ur Rahman  AFG     708
# 2        Matt Henry   NZ     691
# 3    Jasprit Bumrah  IND     690
# 4      Mehedi Hasan  BAN     668

# %%
df53.shape
# Out:
# (10, 3)

# %% [markdown]
# **6.1Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.**

# %%
link61='https://www.icc-cricket.com/rankings/womens/team-rankings/odi'
page61=requests.get(link61)
soup61=bs(page61.content,'html.parser')

# %%
country61=soup61.find_all('span',class_='u-hide-phablet')
country611=[]
for i in range(1,11):
    country611.append(country61[i].get_text())
country611.insert(0,'Australia')
country611
# Out:
# ['Australia',
#  'South Africa',
#  'England',
#  'India',
#  'New Zealand',
#  'West Indies',
#  'Pakistan',
#  'Bangladesh',
#  'Sri Lanka',
#  'Ireland',
#  '']

# %%
match61=soup61.find_all('td',class_='table-body__cell u-center-text')
match611=[]
for i in range(0,18):
    match611.append(match61[i].get_text())
match611[0]
# Out:
# ['24',
#  '2,828',
#  '17',
#  '1,993',
#  '20',
#  '2,226',
#  '21',
#  '1,947',
#  '12',
#  '1,025',
#  '15',
#  '1,101',
#  '5',
#  '306',
#  '11',
#  '519',
#  '2',
#  '25']

# %%
match611[0]
# Out:
# '24'

# %%
Match611=[]
Points611=[]
for i in range(0,18,2):
    Match611.append(match611[i])
Match611
# Out:
# ['24', '17', '20', '21', '12', '15', '5', '11', '2']

# %%
for i in range(1,18,2):
    Points611.append(match611[i])
Points611
# Out:
# ['2,828', '1,993', '2,226', '1,947', '1,025', '1,101', '306', '519', '25']

# %%
Points611.insert(0,'2955')

# %%
Match611.insert(0,'18')

# %%
Rating61=soup61.find_all('td',class_='table-body__cell u-text-right rating')
Rating611=[]
for i in range(0,9):
    Rating611.append(Rating61[i].get_text())
Rating611.insert(0,'164')

# %%
Rating611
# Out:
# ['164', '118', '117', '111', '93', '85', '73', '61', '47', '13']

# %%
df611=pd.DataFrame()

# %%
df611['Country']=country611
df611['Matches']=Match611
df611['Points']=Points611
df611['Ratings']=Rating611

# %%
df611.head()
# Out:
#         Country Matches Points Ratings
# 0     Australia      18   2955     164
# 1  South Africa      24  2,828     118
# 2       England      17  1,993     117
# 3         India      20  2,226     111
# 4   New Zealand      21  1,947      93

# %%
df611.shape
# Out:
# (10, 4)

# %% [markdown]
# **6.2Top 10 women’s ODI players along with the records of their team and rating**

# %%
link62='https://www.icc-cricket.com/rankings/womens/player-rankings/odi'
page62=requests.get(link62)
soup62=bs(page62.content,'html.parser')

# %%
player62=soup62.find_all('td',class_='table-body__cell name')
player621=[]
for i in range(0,9):
    player621.append(player62[i].get_text())
player621[:]=[i.strip('\n') for i in player621]
player621.insert(0,'Tammy Beaumont')
player621
# Out:
# ['Tammy Beaumont',
#  'Lizelle Lee',
#  'Alyssa Healy',
#  'Stafanie Taylor',
#  'Meg Lanning',
#  'Amy Satterthwaite',
#  'Smriti Mandhana',
#  'Mithali Raj',
#  'Natalie Sciver',
#  'Laura Wolvaardt']

# %%
country62=soup62.find_all('span',class_='table-body__logo-text')
country621=[]
for i in range(0,9):
    country621.append(country62[i].get_text())
country621[:]=[i.strip('\n') for i in country621]
country621.insert(0,'ENG')
country621
# Out:
# ['ENG', 'SA', 'AUS', 'WI', 'AUS', 'NZ', 'IND', 'IND', 'ENG', 'SA']

# %%
rating62=soup62.find_all('td',class_='table-body__cell u-text-right rating')
rating621=[]
for i in range(0,9):
    rating621.append(rating62[i].get_text())
rating621[:]=[i.strip('\n') for i in rating621]
rating621.insert(0,'765')
rating621
# Out:
# ['765', '758', '756', '746', '723', '715', '710', '709', '685', '683']

# %%
df62=pd.DataFrame()
df62['Player']=player621
df62['Country']=country621
df62['Rating']=rating621

# %%
df62.head()
# Out:
#             Player Country Rating
# 0   Tammy Beaumont     ENG    765
# 1      Lizelle Lee      SA    758
# 2     Alyssa Healy     AUS    756
# 3  Stafanie Taylor      WI    746
# 4      Meg Lanning     AUS    723

# %%
df62.shape
# Out:
# (10, 3)

# %% [markdown]
# **6.3Top 10 women’s ODI all-rounder along with the records of their team and rating**

# %%
link63='https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder'
page63=requests.get(link63)
soup63=bs(page63.content,'html.parser')

# %%
player63=soup63.find_all('td',class_='table-body__cell rankings-table__name name')
player631=[]
for i in range(0,9):
    player631.append(player63[i].get_text())
player631[:]=[i.strip('\n') for i in player631]
player631.insert(0,'Marizanne Kapp')
player631
# Out:
# ['Marizanne Kapp',
#  'Ellyse Perry',
#  'Stafanie Taylor',
#  'Natalie Sciver',
#  'Deepti Sharma',
#  'Jess Jonassen',
#  'Ashleigh Gardner',
#  'Dane van Niekerk',
#  'Sophie Devine',
#  'Amelia Kerr']

# %%
country63=soup63.find_all('span',class_='table-body__logo-text')
country631=[]
for i in range(0,9):
    country631.append(country63[i].get_text())
country631.insert(0,'SA')
country631
# Out:
# ['SA', 'AUS', 'WI', 'ENG', 'IND', 'AUS', 'AUS', 'SA', 'NZ', 'NZ']

# %%
rating63=soup63.find_all('td',class_='table-body__cell rating')
rating631=[]
for i in range(0,9):
    rating631.append(rating63[i].get_text())
rating631[:]=[i.strip('\n') for i in rating631]
rating631.insert(0,'418')
rating631
# Out:
# ['418', '418', '410', '349', '343', '307', '252', '243', '242', '236']

# %%
df63=pd.DataFrame()
df63['Player']=player631
df63['Country']=country631
df63['Rating']=rating631

# %%
df63.head()
# Out:
#             Player Country Rating
# 0   Marizanne Kapp      SA    418
# 1     Ellyse Perry     AUS    418
# 2  Stafanie Taylor      WI    410
# 3   Natalie Sciver     ENG    349
# 4    Deepti Sharma     IND    343

# %%
df63.shape
# Out:
# (10, 3)

# %% [markdown]
# **7.Write a python program to scrape details of all the mobile phones under Rs. 20,000 listed on Amazon.in. The
# scraped data should include Product Name, Price, Image URL and Average Rating**

# %%
link7='https://www.amazon.in/s?k=mobile+phones+under+20000&crid=C8PLV2WQLDT9&sprefix=mobile+phones+under%2Caps%2C369&ref=nb_sb_ss_ts-doa-p_4_19'
page7=requests.get(link7)
#soup7=bs(page7.content,'html.parser')
page7
# Out:
# <Response [200]>

# %%
soup7=bs(page7.content,'html.parser')

# %%
name7=soup7.find_all('span',class_='a-size-medium a-color-base a-text-normal')

# %%
name71=[]
for i in range(0,len(name7)):
    name71.append(name7[i].get_text())
name71
# Out:
# ['Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage)| 5000 mAh| 2.3GHz Mediatek Helio G35 Octa core Processor',
#  'Redmi 9A (Nature Green, 2GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery',
#  'Oppo A31 (Fantasy White, 6GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Samsung Galaxy M31 (Ocean Blue, 6GB RAM, 128GB Storage)',
#  'Redmi Note 10 (Shadow Black, 6GB RAM, 128GB Storage)',
#  'Samsung Galaxy M31s (Mirage Blue, 6GB RAM, 128GB Storage)',
#  'Samsung Galaxy M12 (Blue,6GB RAM, 128GB Storage) 6000 mAh with 8nm Processor | True 48 MP Quad Camera | 90Hz Refresh Rate',
#  'Samsung Galaxy M21 (Midnight Blue, 4GB RAM, 64GB Storage)',
#  'Redmi 9A (Sea Blue 2GB RAM 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery',
#  'Samsung Galaxy M12 (Black,6GB RAM, 128GB Storage) 6000 mAh with 8nm Processor | True 48 MP Quad Camera | 90Hz Refresh Rate',
# ...

# %%
len(name71)
# Out:
# 16

# %%
price7=soup7.find_all('span',class_='a-price-whole')

# %%
price71=[]
for i in range(0,len(price7)):
    price71.append(price7[i].get_text())
price71
# Out:
# ['8,799',
#  '6,999',
#  '10,990',
#  '14,999',
#  '14,499',
#  '16,999',
#  '12,499',
#  '12,499',
#  '6,999',
#  '12,499',
#  '10,000',
#  '5,000',
#  '14,499',
#  '7,490',
#  '6,999',
#  '10,990']

# %%
image7=soup7.find_all('img',class_='s-image')
len(image7)
# Out:
# 16

# %%
import re
images71=[]
for img in soup7.findAll('img'):
    images71.append(img.get('src'))

# %%
images711=images71[2:]

# %%
images711
# Out:
# ['https://m.media-amazon.com/images/I/71A9Vo1BatL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71sxlhYhKWL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/61IhTtJUXJL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71-Su4Wr0HL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/715t-uJnjMS._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/61d-phh4GfL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71yYaNztZ0L._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71dujTTJDZL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71sxlhYhKWL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/714QWDxXgNL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71U2SiHgbiL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/41QsvcpKaZL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71-BcSc9rhS._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/51FnmxwFHDL._AC_UY218_.jpg',
# ...

# %%
rating7=soup7.find_all('span',class_='a-icon-alt')

# %%
rating71=rating7[0:-4]

# %%
len(rating71)
# Out:
# 16

# %%
df71=pd.DataFrame()
df71['Mobile Name']=name71
df71['Mobile Price']=price71
df71['Image URL']=images711
df71['Mobile Ratings']=rating71

# %%
df71.head()
# Out:
#                                          Mobile Name Mobile Price  \
# 0  Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage)| 500...        8,799
# 1  Redmi 9A (Nature Green, 2GB RAM, 32GB Storage)...        6,999
# 2  Oppo A31 (Fantasy White, 6GB RAM, 128GB Storag...       10,990
# 3  Samsung Galaxy M31 (Ocean Blue, 6GB RAM, 128GB...       14,999
# 4  Redmi Note 10 (Shadow Black, 6GB RAM, 128GB St...       14,499
#
#                                            Image URL        Mobile Ratings
# 0  https://m.media-amazon.com/images/I/71A9Vo1Bat...  [4.2 out of 5 stars]
# 1  https://m.media-amazon.com/images/I/71sxlhYhKW...  [4.2 out of 5 stars]
# 2  https://m.media-amazon.com/images/I/61IhTtJUXJ...  [4.2 out of 5 stars]
# 3  https://m.media-amazon.com/images/I/71-Su4Wr0H...  [4.3 out of 5 stars]
# 4  https://m.media-amazon.com/images/I/715t-uJnjM...  [4.0 out of 5 stars]

# %%
link70='https://www.amazon.in/s?k=mobile+phones+under+20000&page=2&crid=C8PLV2WQLDT9&qid=1621875058&sprefix=mobile+phones+under%2Caps%2C369&ref=sr_pg_2'
page70=requests.get(link70)
#soup7=bs(page7.content,'html.parser')
page70
# Out:
# <Response [200]>

# %%
soup70=bs(page70.content,'html.parser')
name70=soup70.find_all('span',class_='a-size-medium a-color-base a-text-normal')
name701=[]
for i in range(0,len(name70)):
    name701.append(name70[i].get_text())
name701
# Out:
# ['Samsung Galaxy M12 (Black,4GB RAM, 64GB Storage) 6000 mAh with 8nm Processor | True 48 MP Quad Camera | 90Hz Refresh Rate',
#  'Vivo Y91i (Ocean Blue, 3GB RAM, 32GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Vivo Y91i (Fusion Black, 2GB RAM, 32GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Redmi Note 9 (Pebble Grey, 4GB RAM 64GB Storage) - 48MP Quad Camera & Full HD+ Display',
#  'Samsung Galaxy M02s (Blue,4GB RAM, 64GB Storage) | 5000 mAh | Triple Camera',
#  'Samsung Galaxy M21 (Raven Black, 4GB RAM, 64GB Storage)',
#  'Samsung Galaxy M01 Core (Black, 2GB RAM, 32GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Samsung Galaxy M12 (Blue,4GB RAM, 64GB Storage) 6000 mAh with 8nm Processor | True 48 MP Quad Camera | 90Hz Refresh Rate',
#  'Redmi Note 10 (Aqua Green, 4GB RAM, 64GB Storage)',
#  'Redmi 9 (Carbon Black, 4GB RAM, 64GB Storage) | 5000 mAh| 2.3GHz Mediatek Helio G35 Octa core Processor',
# ...

# %%
len(name701)
# Out:
# 16

# %%
price70=soup70.find_all('span',class_='a-price-whole')

# %%
price701=[]
for i in range(0,len(price70)):
    price701.append(price70[i].get_text())
price701
# Out:
# ['9,999',
#  '7,990',
#  '7,490',
#  '10,999',
#  '9,999',
#  '12,499',
#  '6,199',
#  '9,999',
#  '12,499',
#  '8,799',
#  '17,990',
#  '8,499',
#  '13,990',
#  '12,999',
#  '9,990',
#  '6,799']

# %%
image70=soup70.find_all('img',class_='s-image')
image70
# Out:
# [<img alt="Samsung Galaxy M12 (Black,4GB RAM, 64GB Storage) 6000 mAh with 8nm Processor | True 48 MP Quad Camera | 90Hz Refresh Rate" class="s-image" data-image-index="17" data-image-latency="s-product-image" data-image-load="" data-image-source-density="1" src="https://m.media-amazon.com/images/I/714QWDxXgNL._AC_UY218_.jpg" srcset="https://m.media-amazon.com/images/I/714QWDxXgNL._AC_UY218_.jpg 1x, https://m.media-amazon.com/images/I/714QWDxXgNL._AC_UY327_QL65_.jpg 1.5x, https://m.media-amazon.com/images/I/714QWDxXgNL._AC_UY436_QL65_.jpg 2x, https://m.media-amazon.com/images/I/714QWDxXgNL._AC_UY545_QL65_.jpg 2.5x, https://m.media-amazon.com/images/I/714QWDxXgNL._AC_UY654_QL65_.jpg 3x"/>,
# ...

# %%
images701=[]
for img in soup70.findAll('img'):
    images701.append(img.get('src'))

# %%
images701=images701[2:]

# %%
len(images701)
# Out:
# 16

# %%
ratings70=soup70.find_all('i',class_='a-icon a-icon-star-small a-star-small-4 aok-align-bottom')
ratings701=[]
for i in range(0,len(ratings70)):
    ratings701.append(ratings70[i].get_text())
ratings70
# Out:
# [<i class="a-icon a-icon-star-small a-star-small-4 aok-align-bottom"><span class="a-icon-alt">4.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star-small a-star-small-4 aok-align-bottom"><span class="a-icon-alt">4.2 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star-small a-star-small-4 aok-align-bottom"><span class="a-icon-alt">4.2 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star-small a-star-small-4 aok-align-bottom"><span class="a-icon-alt">4.1 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star-small a-star-small-4 aok-align-bottom"><span class="a-icon-alt">4.2 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star-small a-star-small-4 aok-align-bottom"><span class="a-icon-alt">4.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star-small a-star-small-4 aok-align-bottom"><span class="a-icon-alt">4.0 out of 5 stars</span></i>,
# ...

# %%
ratings701.insert(4,'4.1 out of 5 stars')

# %%
df701=pd.DataFrame()
df701['Mobile Name']=name701
df701['Mobile Price']=price701
df701['Image URL']=images701
df701['Mobile Ratings']=ratings701

# %%
df701.head()
# Out:
#                                          Mobile Name Mobile Price  \
# 0  Samsung Galaxy M12 (Black,4GB RAM, 64GB Storag...        9,999
# 1  Vivo Y91i (Ocean Blue, 3GB RAM, 32GB Storage) ...        7,990
# 2  Vivo Y91i (Fusion Black, 2GB RAM, 32GB Storage...        7,490
# 3  Redmi Note 9 (Pebble Grey, 4GB RAM 64GB Storag...       10,999
# 4  Samsung Galaxy M02s (Blue,4GB RAM, 64GB Storag...        9,999
#
#                                            Image URL      Mobile Ratings
# 0  https://m.media-amazon.com/images/I/714QWDxXgN...  4.0 out of 5 stars
# 1  https://m.media-amazon.com/images/I/51-T19jXch...  3.8 out of 5 stars
# 2  https://m.media-amazon.com/images/I/51ZoulFBPG...  4.0 out of 5 stars
# 3  https://m.media-amazon.com/images/I/71X5I1cVfb...  4.2 out of 5 stars
# 4  https://m.media-amazon.com/images/I/71wkpcIfqd...  4.1 out of 5 stars

# %%
df71.append(df701, ignore_index = True)
# Out:
#                                           Mobile Name Mobile Price  \
# 0   Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage)| 500...        8,799
# 1   Redmi 9A (Nature Green, 2GB RAM, 32GB Storage)...        6,999
# 2   Oppo A31 (Fantasy White, 6GB RAM, 128GB Storag...       10,990
# 3   Samsung Galaxy M31 (Ocean Blue, 6GB RAM, 128GB...       14,999
# 4   Redmi Note 10 (Shadow Black, 6GB RAM, 128GB St...       14,499
# 5   Samsung Galaxy M31s (Mirage Blue, 6GB RAM, 128...       16,999
# 6   Samsung Galaxy M12 (Blue,6GB RAM, 128GB Storag...       12,499
# 7   Samsung Galaxy M21 (Midnight Blue, 4GB RAM, 64...       12,499
# 8   Redmi 9A (Sea Blue 2GB RAM 32GB Storage) | 2GH...        6,999
# 9   Samsung Galaxy M12 (Black,6GB RAM, 128GB Stora...       12,499
# 10  Redmi 9 Prime (Sunrise Flare, 4GB RAM, 64GB St...       10,000
# 11  Panasonic Eluga i7 (2GB RAM, 16GB Storage, Fin...        5,000
# 12  Redmi Note 10 (Aqua Green, 6GB RAM, 128GB Stor...       14,499
# ...

# %% [markdown]
# **8.Write a python program to extract information about the local weather from the National Weather Service
# website of USA, https://www.weather.gov/ for the city, San Francisco. You need to extract data about 7 day
# extended forecast display for the city. The data should include period, short description, temperature and
# description.**

# %%
link8='https://forecast.weather.gov/MapClick.php?lat=37.777120000000025&lon=-122.41963999999996#.YKvq5BozbIU'

# %%
page8=requests.get(link8)

# %%
page8
# Out:
# <Response [200]>

# %%
soup8=bs(page8.content,'html.parser')

# %%
periods8=soup8.find_all('div',class_='col-sm-2 forecast-label')
periods8
# Out:
# [<div class="col-sm-2 forecast-label"><b>Today</b></div>,
#  <div class="col-sm-2 forecast-label"><b>Tonight</b></div>,
#  <div class="col-sm-2 forecast-label"><b>Tuesday</b></div>,
#  <div class="col-sm-2 forecast-label"><b>Tuesday Night</b></div>,
#  <div class="col-sm-2 forecast-label"><b>Wednesday</b></div>,
#  <div class="col-sm-2 forecast-label"><b>Wednesday Night</b></div>,
#  <div class="col-sm-2 forecast-label"><b>Thursday</b></div>,
#  <div class="col-sm-2 forecast-label"><b>Thursday Night</b></div>,
#  <div class="col-sm-2 forecast-label"><b>Friday</b></div>,
#  <div class="col-sm-2 forecast-label"><b>Friday Night</b></div>,
#  <div class="col-sm-2 forecast-label"><b>Saturday</b></div>,
#  <div class="col-sm-2 forecast-label"><b>Saturday Night</b></div>,
#  <div class="col-sm-2 forecast-label"><b>Sunday</b></div>]

# %%
periods81=[]
for i in range(0,13,2):
    periods81.append(periods8[i].get_text())
periods81
# Out:
# ['Today', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
short8=soup8.find_all('div',class_='col-sm-10 forecast-text')
short8
# Out:
# [<div class="col-sm-10 forecast-text">Sunny, with a high near 66. Breezy, with a west wind 7 to 12 mph increasing to 17 to 22 mph in the afternoon. Winds could gust as high as 29 mph. </div>,
#  <div class="col-sm-10 forecast-text">Increasing clouds, with a low around 52. Breezy, with a west wind 16 to 23 mph, with gusts as high as 30 mph. </div>,
#  <div class="col-sm-10 forecast-text">Mostly cloudy through mid morning, then gradual clearing, with a high near 65. West wind 15 to 21 mph, with gusts as high as 26 mph. </div>,
#  <div class="col-sm-10 forecast-text">Mostly clear, with a low around 50. West wind 15 to 20 mph decreasing to 8 to 13 mph after midnight. Winds could gust as high as 25 mph. </div>,
#  <div class="col-sm-10 forecast-text">Sunny, with a high near 65. Breezy, with a west wind 7 to 12 mph increasing to 20 to 25 mph in the afternoon. Winds could gust as high as 32 mph. </div>,
# ...

# %%
short81=[]
for i in range(0,13,2):
    short81.append(short8[i].get_text())
len(short81)
# Out:
# 7

# %%
temp=['High: 66 °F','High: 65 °F','High: 65 °F','High: 66 °F','High: 66 °F','High: 64 °F','High: 66 °F']

# %%
df8=pd.DataFrame()

# %%
df8['Period']=periods81
df8['Short Description']=short81
df8['Temparature']=temp

# %%
df8.head()
# Out:
#       Period                                  Short Description  Temparature
# 0      Today  Sunny, with a high near 66. Breezy, with a wes...  High: 66 °F
# 1    Tuesday  Mostly cloudy through mid morning, then gradua...  High: 65 °F
# 2  Wednesday  Sunny, with a high near 65. Breezy, with a wes...  High: 65 °F
# 3   Thursday                        Sunny, with a high near 66.  High: 66 °F
# 4     Friday                 Mostly sunny, with a high near 66.  High: 66 °F

# %%
df8.shape
# Out:
# (7, 3)

# %% [markdown]
# **9.Write a python program to scrape fresher job listings from ‘https://internshala.com/’. It should include job title,
# company name, CTC, and apply date.**

# %%
link9='https://internshala.com/fresher-jobs/page-1'

# %%
page9=requests.get(link9)

# %%
page9
# Out:
# <Response [200]>

# %%
soup9=bs(page9.content,'html.parser')

# %%
#jobtitle
title9=soup9.find_all('div',class_='heading_4_5 profile')
title90=[]
for i in range(0,len(title9)):
    title90.append(title9[i].get_text())
title90[:]=[i.lstrip('\n') for i in title90]
title90
# Out:
# ['Android App Developer ',
#  'Associate Data Scientist ',
#  'Junior Software Developer ',
#  'Associate Software Developer ',
#  'Full Stack Developer ',
#  'Operations Executive ',
#  'Associate UI/UX Designer ',
#  'Web Development Trainee ',
#  'Business Development Executive ',
#  'Vendor Success Manager ',
#  'Full Stack Flutter Developer ',
#  'Telemarketing Sales Associate ',
#  'Associate Software Developer ',
#  'Hardware Simulation Engineer ',
#  'Graphic Designer ',
#  'Marketing Analyst ',
#  'Mobile App Developer ',
#  'Software Engineer - AI(NLP)/Front-end(Angular)/Back-end(Python/Java Cloud) ',
#  'Corporate Sales Executive ',
#  'Software Tester ',
#  'Mobile App Developer ',
#  'Junior Backend Developer ',
#  'Social Media Strategist And Copywriter ',
#  'Junior UI Designer ',
#  'Customer Service Executive ',
#  'Business Development Associate ',
#  'JavaScript Developer ',
#  'Software Engineer ',
#  'Business Development Manager (Inside Sales) ',
# ...

# %%
#company name
company9=soup9.find_all('a',class_='link_display_like_text')
company90=[]
for i in range(0,len(company9)):
    company90.append(company9[i].get_text())
company90[:]=[i.lstrip('\n') for i in company90]
comp=[]
for i in range(0,len(company90)):
    comp.append(company90[i][24:])
comp
# Out:
# ['Storlyy                    ',
#  'Softsensor.ai                    ',
#  'ZoryBoard Software Solutions                    ',
#  'SNet Labs Private Limited                    ',
#  'RavGins International Private Limited (Wobb.ai)                    ',
#  'TutorBin                    ',
#  'RavGins International Private Limited (Wobb.ai)                    ',
#  'Softsensor.ai                    ',
#  'Square Select Estates                    ',
#  'Little Olive                    ',
#  'HeartShirt                    ',
#  'StrategyCo.Global                    ',
#  'Labellerr By Tensor Matics Private Limited                    ',
#  'Keysight Technologies                    ',
#  'Cynfas                    ',
#  'Exhilar Innovative Solutions Private Limited                    ',
#  'Wow Labz                    ',
#  'RapidKen.AI                    ',
#  'Twin Health                    ',
#  'Lattice Innovations Private Limited                    ',
# ...

# %%
#ctc
ctc=soup9.find_all('div',class_='item_body')
ctc9=[]
for i in range(0,len(ctc)):
    ctc9.append(ctc[i].get_text())
ctc9[:]=[i.strip('\n') for i in ctc9]
# Out:
# ['Starts\xa0Immediately\n                        ',
#  '  3 - 3.5 LPA                                                    ',
#  "23 Jun' 21",
#  'Starts\xa0Immediately\n                        ',
#  '  4 - 8 LPA                                                    ',
#  "23 Jun' 21",
#  'Starts\xa0Immediately\n                        ',
#  '  3 - 4 LPA                                                    ',
#  "20 Jun' 21",
#  'Starts\xa0Immediately\n                        ',
#  '  3 - 3.2 LPA                                                    ',
#  "20 Jun' 21",
#  'Starts\xa0Immediately\n                        ',
#  '  3.3 - 4 LPA                                                    ',
#  "20 Jun' 21",
#  'Starts\xa0Immediately\n                        ',
#  '  3.6 - 3.84 LPA                                                    ',
#  "20 Jun' 21",
#  'Starts\xa0Immediately\n                        ',
#  '  3 - 4 LPA                                                    ',
#  "20 Jun' 21",
# ...

# %%
ctc10=[]
for i in range(1,120,3):
    ctc10.append(ctc9[i])
ctc10
# Out:
# ['  3 - 3.5 LPA                                                    ',
#  '  4 - 8 LPA                                                    ',
#  '  3 - 4 LPA                                                    ',
#  '  3 - 3.2 LPA                                                    ',
#  '  3.3 - 4 LPA                                                    ',
#  '  3.6 - 3.84 LPA                                                    ',
#  '  3 - 4 LPA                                                    ',
#  '  3 - 5 LPA                                                    ',
#  '  3 - 5 LPA                                                    ',
#  '  3 - 3.5 LPA                                                    ',
#  '  3 - 3.5 LPA                                                    ',
#  '  3 - 5 LPA                                                    ',
#  '  7 - 10 LPA                                                    ',
#  '  4 - 7 LPA                                                    ',
# ...

# %%
#apply date
app=soup9.find_all('div',class_='item_body')
app9=[]
for i in range(0,len(app)):
    app9.append(app[i].get_text())
app9
# Out:
# ['\nStarts\xa0Immediately\n                        ',
#  '\n  3 - 3.5 LPA                                                    ',
#  "23 Jun' 21",
#  '\nStarts\xa0Immediately\n                        ',
#  '\n  4 - 8 LPA                                                    ',
#  "23 Jun' 21",
#  '\nStarts\xa0Immediately\n                        ',
#  '\n  3 - 4 LPA                                                    ',
#  "20 Jun' 21",
#  '\nStarts\xa0Immediately\n                        ',
#  '\n  3 - 3.2 LPA                                                    ',
#  "20 Jun' 21",
#  '\nStarts\xa0Immediately\n                        ',
#  '\n  3.3 - 4 LPA                                                    ',
#  "20 Jun' 21",
#  '\nStarts\xa0Immediately\n                        ',
#  '\n  3.6 - 3.84 LPA                                                    ',
#  "20 Jun' 21",
#  '\nStarts\xa0Immediately\n                        ',
# ...

# %%
app10=[]
for i in range(2,120,3):
    app10.append(app9[i])
app10
# Out:
# ["23 Jun' 21",
#  "23 Jun' 21",
#  "20 Jun' 21",
#  "20 Jun' 21",
#  "20 Jun' 21",
#  "20 Jun' 21",
#  "20 Jun' 21",
#  "20 Jun' 21",
#  "19 Jun' 21",
#  "19 Jun' 21",
#  "19 Jun' 21",
#  "19 Jun' 21",
#  "23 Jun' 21",
#  "19 Jun' 21",
#  "17 Jun' 21",
#  "17 Jun' 21",
#  "17 Jun' 21",
#  "17 Jun' 21",
#  "17 Jun' 21",
#  "16 Jun' 21",
#  "16 Jun' 21",
#  "16 Jun' 21",
#  "16 Jun' 21",
#  "15 Jun' 21",
#  "14 Jun' 21",
#  "14 Jun' 21",
#  "13 Jun' 21",
#  "13 Jun' 21",
#  "13 Jun' 21",
#  "12 Jun' 21",
#  "12 Jun' 21",
#  "12 Jun' 21",
#  "12 Jun' 21",
#  "12 Jun' 21",
#  "12 Jun' 21",
#  "12 Jun' 21",
#  "12 Jun' 21",
#  "11 Jun' 21",
#  "11 Jun' 21",
#  "11 Jun' 21"]

# %%
dfl=pd.DataFrame()
dfl['Job Title']=title90
dfl['Company Name']=comp
dfl['CTC']=ctc10
dfl['Apply Date']=app10

# %%
dfl.head()
# Out:
#                        Job Title  \
# 0         Android App Developer
# 1      Associate Data Scientist
# 2     Junior Software Developer
# 3  Associate Software Developer
# 4          Full Stack Developer
#
#                                         Company Name  \
# 0                        Storlyy
# 1                  Softsensor.ai
# 2   ZoryBoard Software Solutions
# 3      SNet Labs Private Limited
# 4  RavGins International Private Limited (Wobb.ai...
#
#                                                  CTC  Apply Date
# 0    3 - 3.5 LPA                                 ...  23 Jun' 21
# 1    4 - 8 LPA                                   ...  23 Jun' 21
# 2    3 - 4 LPA                                   ...  20 Jun' 21
# 3    3 - 3.2 LPA                                 ...  20 Jun' 21
# 4    3.3 - 4 LPA                                 ...  20 Jun' 21

# %%
dfl.shape
# Out:
# (40, 4)

# %%
link10='https://internshala.com/fresher-jobs/page-2'
page10=requests.get(link10)
page10
# Out:
# <Response [200]>

# %%
soup10=bs(page10.content,'html.parser')

# %%
#jobtitle
title10=soup10.find_all('div',class_='heading_4_5 profile')
title11=[]
for i in range(0,len(title10)):
    title11.append(title10[i].get_text())
title11[:]=[i.lstrip('\n') for i in title11]
title11
# Out:
# ['Backend Developer ',
#  'Software Engineer ',
#  'Python Developer ',
#  'Front End Developer ',
#  'Business Development Associate ',
#  'Associate Software Developer ',
#  'Content Writer (Sales) ',
#  'C++ Developer ',
#  'Front End Developer ',
#  'Digital Illustrator ',
#  'Legal Research Professional ',
#  'Business Marketing Manager ',
#  'Front End Developer ',
#  'Web Developer ',
#  'Android App Developer ',
#  'Software Engineer ',
#  'Advanced Math Content Writer ',
#  'Junior Front End Developer ',
#  'Software Engineer (PHP) ',
#  'Doctor ',
#  'Full Stack Engineer ',
#  'Backend Developer ',
#  'Growth Executive (sales) ',
#  'Android App Developer ',
#  'Blockchain Developer ',
#  'International Business Development & Service (Operations) Associate ',
#  'Data Scientist ',
#  'Finance And Administrative Analyst ',
#  'Associate Front End Developer - Shopify ',
#  'Junior Full Stack Developer ',
#  'Backend Developer ',
#  'Executive Assistant ',
# ...

# %%
#ctc
ctc10=soup10.find_all('div',class_='item_body')
ctc11=[]
for i in range(0,len(ctc10)):
    ctc11.append(ctc10[i].get_text())
ctc11[:]=[i.strip('\n') for i in ctc11]
ctc12=[]
for i in range(1,120,3):
    ctc12.append(ctc11[i])
ctc12
# Out:
# ['  3 - 5 LPA                                                    ',
#  '  3 - 4.5 LPA                                                    ',
#  '  3.5 - 4.5 LPA                                                    ',
#  '  7 - 8.5 LPA                                                    ',
#  '  3 - 4 LPA                                                    ',
#  '  3.2 - 5.5 LPA                                                    ',
#  '  3 LPA                                                    ',
#  '  4 - 8.5 LPA                                                    ',
#  '  3 - 6 LPA                                                    ',
#  '  6.6 - 8.28 LPA                                                    ',
#  '  3 - 6 LPA                                                    ',
#  '  4.2 - 8.5 LPA                                                    ',
#  '  3 LPA                                                    ',
#  '  3 LPA                                                    ',
# ...

# %%
#apply date
appl=soup10.find_all('div',class_='item_body')
appl1=[]
for i in range(0,len(appl)):
    appl1.append(appl[i].get_text())
appl2=[]
for i in range(2,120,3):
    appl2.append(appl1[i])
appl2
# Out:
# ["10 Jun' 21",
#  "10 Jun' 21",
#  "9 Jun' 21",
#  "9 Jun' 21",
#  "9 Jun' 21",
#  "9 Jun' 21",
#  "9 Jun' 21",
#  "9 Jun' 21",
#  "9 Jun' 21",
#  "6 Jun' 21",
#  "6 Jun' 21",
#  "6 Jun' 21",
#  "5 Jun' 21",
#  "5 Jun' 21",
#  "5 Jun' 21",
#  "5 Jun' 21",
#  "4 Jun' 21",
#  "4 Jun' 21",
#  "4 Jun' 21",
#  "4 Jun' 21",
#  "4 Jun' 21",
#  "4 Jun' 21",
#  "4 Jun' 21",
#  "3 Jun' 21",
#  "3 Jun' 21",
#  "3 Jun' 21",
#  "3 Jun' 21",
#  "2 Jun' 21",
#  "2 Jun' 21",
#  "30 May' 21",
#  "30 May' 21",
#  "30 May' 21",
#  "29 May' 21",
#  "29 May' 21",
#  "29 May' 21",
#  "28 May' 21",
#  "28 May' 21",
#  "27 May' 21",
#  "19 Jun' 21",
#  "27 May' 21"]

# %%
#company name
company10=soup10.find_all('a',class_='link_display_like_text')
company11=[]
for i in range(0,len(company10)):
    company11.append(company10[i].get_text())
company11[:]=[i.lstrip('\n') for i in company11]
comp1=[]
for i in range(0,len(company11)):
    comp1.append(company11[i][24:])
comp1
# Out:
# ['Reportcard                    ',
#  'Bluebird India R&D Center Private Limited                    ',
#  'Vindiata Consulting Private Limited                    ',
#  'HomeJam                    ',
#  'Mr n Mrs Pet                    ',
#  'NDS Infotech                    ',
#  'Leadgenerator                    ',
#  'Ascentspark Software Private Limited                    ',
#  'Ascentspark Software Private Limited                    ',
#  'Internshala                    ',
#  'Atul Dhadiwal                    ',
#  'MentorBoxx                    ',
#  'White Blink                    ',
#  'Software Lab                    ',
#  'WebMOBI                    ',
#  'Fintech Global Center                    ',
#  'Digituala Lab Enterprise LLP                    ',
#  'Zensark Technologies Private Limited                    ',
#  'WisdmLabs                    ',
#  'Spaces And Between                    ',
#  'Softway Solutions Private Limited                    ',
# ...

# %%
dfl1=pd.DataFrame()
dfl1['Job Title']=title11
dfl1['Company Name']=comp1
dfl1['CTC']=ctc12
dfl1['Apply Date']=appl2

# %%
dfl1.head()
# Out:
#                          Job Title  \
# 0               Backend Developer
# 1               Software Engineer
# 2                Python Developer
# 3             Front End Developer
# 4  Business Development Associate
#
#                                         Company Name  \
# 0                     Reportcard
# 1  Bluebird India R&D Center Private Limited     ...
# 2  Vindiata Consulting Private Limited           ...
# 3                        HomeJam
# 4                   Mr n Mrs Pet
#
#                                                  CTC  Apply Date
# 0    3 - 5 LPA                                   ...  10 Jun' 21
# 1    3 - 4.5 LPA                                 ...  10 Jun' 21
# 2    3.5 - 4.5 LPA                               ...   9 Jun' 21
# 3    7 - 8.5 LPA                                 ...   9 Jun' 21
# 4    3 - 4 LPA                                   ...   9 Jun' 21

# %%
dfl1.shape
# Out:
# (40, 4)

# %%
link11='https://internshala.com/fresher-jobs/page-3'
page11=requests.get(link11)
page11
# Out:
# <Response [200]>

# %%
soup11=bs(page11.content,'html.parser')

# %%
#jobtitle
titlel=soup11.find_all('div',class_='heading_4_5 profile')
titlel1=[]
for i in range(0,len(titlel)):
    titlel1.append(titlel[i].get_text())
titlel1[:]=[i.lstrip('\n') for i in titlel1]
titlel1
# Out:
# ['Marketing Manager ',
#  'Backend Developer ',
#  'Full Stack Developer ',
#  'HR Executive ',
#  'International Business Development Associate ']

# %%
#ctc
ctcl=soup11.find_all('div',class_='item_body')
ctcl1=[]
for i in range(0,len(ctcl)):
    ctcl1.append(ctcl[i].get_text())
ctcl1[:]=[i.strip('\n') for i in ctcl1]
ctcl2=[]
for i in range(1,15,3):
    ctcl2.append(ctcl1[i])
ctcl2
# Out:
# ['  3 LPA                                                    ',
#  '  4.2 LPA                                                    ',
#  '  5 LPA                                                    ',
#  '  3 - 4 LPA                                                    ',
#  '  4 - 7 LPA                                                    ']

# %%
#apply date
appk=soup11.find_all('div',class_='item_body')
appk1=[]
for i in range(0,len(appk)):
    appk1.append(appk[i].get_text())
appk2=[]
for i in range(2,15,3):
    appk2.append(appk1[i])
appk2
# Out:
# ["26 May' 21", "26 May' 21", "26 May' 21", "29 May' 21", "3 Jun' 21"]

# %%
#company name
companyk=soup11.find_all('a',class_='link_display_like_text')
companyk1=[]
for i in range(0,len(companyk)):
    companyk1.append(companyk[i].get_text())
companyk1[:]=[i.lstrip('\n') for i in companyk1]
compk2=[]
for i in range(0,len(companyk1)):
    compk2.append(companyk1[i][24:])
compk2
# Out:
# ['Kalaghar                    ',
#  'X0PA AI Private Limited                    ',
#  'DailyKit                    ',
#  'TaraSpan Solutions Private Limited                    ',
#  'HOSS - House Of Soft Skills                    ']

# %%
dfl2=pd.DataFrame()
dfl2['Job Title']=titlel1
dfl2['Company Name']=compk2
dfl2['CTC']=ctcl2
dfl2['Apply Date']=appk2

# %%
dfl2.head()
# Out:
#                                        Job Title  \
# 0                             Marketing Manager
# 1                             Backend Developer
# 2                          Full Stack Developer
# 3                                  HR Executive
# 4  International Business Development Associate
#
#                                         Company Name  \
# 0                       Kalaghar
# 1        X0PA AI Private Limited
# 2                       DailyKit
# 3  TaraSpan Solutions Private Limited            ...
# 4    HOSS - House Of Soft Skills
#
#                                                  CTC  Apply Date
# 0    3 LPA                                       ...  26 May' 21
# 1    4.2 LPA                                     ...  26 May' 21
# 2    5 LPA                                       ...  26 May' 21
# 3    3 - 4 LPA                                   ...  29 May' 21
# 4    4 - 7 LPA                                   ...   3 Jun' 21

# %%
a=dfl.append(dfl1, ignore_index = True)

# %%
a.shape
# Out:
# (80, 4)

# %%
Internshala=a.append(dfl2, ignore_index = True)

# %%
Internshala.shape
# Out:
# (85, 4)

# %%
Internshala.head()
# Out:
#                        Job Title  \
# 0         Android App Developer
# 1      Associate Data Scientist
# 2     Junior Software Developer
# 3  Associate Software Developer
# 4          Full Stack Developer
#
#                                         Company Name  \
# 0                        Storlyy
# 1                  Softsensor.ai
# 2   ZoryBoard Software Solutions
# 3      SNet Labs Private Limited
# 4  RavGins International Private Limited (Wobb.ai...
#
#                                                  CTC  Apply Date
# 0    3 - 3.5 LPA                                 ...  23 Jun' 21
# 1    4 - 8 LPA                                   ...  23 Jun' 21
# 2    3 - 4 LPA                                   ...  20 Jun' 21
# 3    3 - 3.2 LPA                                 ...  20 Jun' 21
# 4    3.3 - 4 LPA                                 ...  20 Jun' 21
